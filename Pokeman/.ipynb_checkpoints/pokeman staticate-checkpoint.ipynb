# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load the dataset in pokeman variable
pokeman = pd.read_csv("dataset\\pokemon.csv")

# %%
pokeman.head() # Show the first 5 elements
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokeman.Legendary.unique().sum()
# Out:
# 1

# %%
pokeman.isnull().sum() # Check the null values in the datasets
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokeman[pokeman["Name"].isnull()] # Show the null value
# Out:
#      # Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 62  63  NaN  Fighting    NaN  65     105       60       60       70     95
#
#     Generation  Legendary
# 62           1      False

# %%
pokeman[pokeman["Type 2"].isnull()] # check the null values in Type 2 category pokeman
# Out:
#        #             Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  \
# 4      5       Charmander      Fire    NaN   39      52       43       60
# 5      6       Charmeleon      Fire    NaN   58      64       58       80
# 9     10         Squirtle     Water    NaN   44      48       65       50
# 10    11        Wartortle     Water    NaN   59      63       80       65
# 11    12        Blastoise     Water    NaN   79      83      100       85
# 12    13   Mega Blastoise     Water    NaN   79     103      120      135
# 13    14         Caterpie       Bug    NaN   45      30       35       20
# 14    15          Metapod       Bug    NaN   50      20       55       25
# 24    25          Rattata    Normal    NaN   30      56       35       25
# 25    26         Raticate    Normal    NaN   55      81       60       50
# 28    29            Ekans    Poison    NaN   35      60       44       40
# 29    30            Arbok    Poison    NaN   60      85       69       65
# 30    31          Pikachu  Electric    NaN   35      55       40       50
# 31    32           Raichu  Electric    NaN   60      90       55       90
# 32    33        Sandshrew    Ground    NaN   50      75       85       20
# 33    34        Sandslash    Ground    NaN   75     100      110       45
# 34    35         Nidoran♀    Poison    NaN   55      47       52       40
# 35    36         Nidorina    Poison    NaN   70      62       67       55
# 37    38         Nidoran♂    Poison    NaN   46      57       40       40
# 38    39         Nidorino    Poison    NaN   61      72       57       55
# 40    41         Clefairy     Fairy    NaN   70      45       48       60
# 41    42         Clefable     Fairy    NaN   95      70       73       95
# 42    43           Vulpix      Fire    NaN   38      41       40       50
# 43    44        Ninetales      Fire    NaN   73      76       75       81
# 55    56          Diglett    Ground    NaN   10      55       25       35
# 56    57          Dugtrio    Ground    NaN   35      80       50       50
# 57    58           Meowth    Normal    NaN   40      45       35       40
# 58    59          Persian    Normal    NaN   65      70       60       65
# 59    60          Psyduck     Water    NaN   50      52       48       65
# 60    61          Golduck     Water    NaN   80      82       78       95
# ..   ...              ...       ...    ...  ...     ...      ...      ...
# 721  722         Fennekin      Fire    NaN   40      45       40       62
# 722  723          Braixen      Fire    NaN   59      59       58       90
# 724  725          Froakie     Water    NaN   41      56       40       62
# 725  726        Frogadier     Water    NaN   54      63       52       83
# 727  728         Bunnelby    Normal    NaN   38      36       38       32
# 732  733       Scatterbug       Bug    NaN   38      35       40       27
# 733  734           Spewpa       Bug    NaN   45      22       60       27
# 737  738          Flabébé     Fairy    NaN   44      38       39       61
# 738  739          Floette     Fairy    NaN   54      45       47       75
# 739  740          Florges     Fairy    NaN   78      65       68      112
# 740  741           Skiddo     Grass    NaN   66      65       48       62
# 741  742           Gogoat     Grass    NaN  123     100       62       97
# 742  743          Pancham  Fighting    NaN   67      82       62       46
# 744  745          Furfrou    Normal    NaN   75      80       60       65
# 745  746           Espurr   Psychic    NaN   62      48       54       63
# 746  747    Meowstic Male   Psychic    NaN   74      48       76       83
# 747  748  Meowstic Female   Psychic    NaN   74      48       76       83
# 752  753         Spritzee     Fairy    NaN   78      52       60       63
# 753  754       Aromatisse     Fairy    NaN  101      72       72       99
# 754  755          Swirlix     Fairy    NaN   62      48       66       59
# 755  756         Slurpuff     Fairy    NaN   82      80       86       85
# 762  763        Clauncher     Water    NaN   50      53       62       58
# 763  764        Clawitzer     Water    NaN   71      73       88      120
# 770  771          Sylveon     Fairy    NaN   95      65       65      110
# 774  775            Goomy    Dragon    NaN   45      50       35       55
# 775  776          Sliggoo    Dragon    NaN   68      75       53       83
# 776  777           Goodra    Dragon    NaN   90     100       70      110
# 788  789         Bergmite       Ice    NaN   55      69       85       32
# 789  790          Avalugg       Ice    NaN   95     117      184       44
# 792  793          Xerneas     Fairy    NaN  126     131       95      131
#
#      Sp. Def  Speed  Generation  Legendary
# 4         50     65           1      False
# 5         65     80           1      False
# 9         64     43           1      False
# 10        80     58           1      False
# 11       105     78           1      False
# 12       115     78           1      False
# 13        20     45           1      False
# 14        25     30           1      False
# 24        35     72           1      False
# 25        70     97           1      False
# 28        54     55           1      False
# 29        79     80           1      False
# 30        50     90           1      False
# 31        80    110           1      False
# 32        30     40           1      False
# 33        55     65           1      False
# 34        40     41           1      False
# 35        55     56           1      False
# 37        40     50           1      False
# 38        55     65           1      False
# 40        65     35           1      False
# 41        90     60           1      False
# 42        65     65           1      False
# 43       100    100           1      False
# 55        45     95           1      False
# 56        70    120           1      False
# 57        40     90           1      False
# 58        65    115           1      False
# 59        50     55           1      False
# 60        80     85           1      False
# ..       ...    ...         ...        ...
# 721       60     60           6      False
# 722       70     73           6      False
# 724       44     71           6      False
# 725       56     97           6      False
# 727       36     57           6      False
# 732       25     35           6      False
# 733       30     29           6      False
# 737       79     42           6      False
# 738       98     52           6      False
# 739      154     75           6      False
# 740       57     52           6      False
# 741       81     68           6      False
# 742       48     43           6      False
# 744       90    102           6      False
# 745       60     68           6      False
# 746       81    104           6      False
# 747       81    104           6      False
# 752       65     23           6      False
# 753       89     29           6      False
# 754       57     49           6      False
# 755       75     72           6      False
# 762       63     44           6      False
# 763       89     59           6      False
# 770      130     60           6      False
# 774       75     40           6      False
# 775      113     60           6      False
# 776      150     80           6      False
# 788       35     28           6      False
# 789       46     28           6      False
# 792       98     99           6       True
#
# [386 rows x 12 columns]

# %%
attack_defance = pokeman[["Attack","Defense"]] # get the Attack and defense columns of pokeman datasets

# %%
# showthe histogram of attack and defense columns
attack_defance.plot(kind="hist")
plt.show()

# %%
pokeman["Type 1"].unique() # Check thw unique character of column Type 1
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pokeman["Type 2"].unique() # Check thw unique character of column Type 2
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
pokeman.drop(pokeman["Name"].isnull(),inplace=True) # Drop those rows from columns who name is NaN

# %%
pokeman.fillna(method="ffill",inplace=True) # Fill the NaN value

# %%
pokeman.isnull().sum() # Check the another type null values in pokeman datasets
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
pokeman.Legendary.unique()
# Out:
# array([False,  True], dtype=bool)

# %%
pokeman.shape # check the shape datasets
# Out:
# (798, 12)

# %%
y = pokeman.Legendary # get label values from datasets and store in y variable

# %%
pokeman.drop(["Legendary"],inplace = True,axis=1) # Drop Legendary column from dataset

# %%
pokeman.head() # check first five rows
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire  Poison  39      52       43       60       50
# 5  6     Charmeleon   Fire  Poison  58      64       58       80       65
# 6  7      Charizard   Fire  Flying  78      84       78      109       85
#
#    Speed  Generation
# 2     80           1
# 3     80           1
# 4     65           1
# 5     80           1
# 6    100           1

# %%
ty = np.where(y == True,1,0) # convert to numerical value

# %%
# Funcation for converting String and object to numerical values
def label_encoder(data):
    encoder = LabelEncoder()
    return encoder.fit_transform(data)

# %%
pokeman["Type 1"] = label_encoder(pokeman["Type 1"])

# %%
pokeman["Type 2"] = label_encoder(pokeman["Type 2"])

# %%
pokeman.head()
# Out:
#    #           Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2  3       Venusaur       9      13  80      82       83      100      100
# 3  4  Mega Venusaur       9      13  80     100      123      122      120
# 4  5     Charmander       6      13  39      52       43       60       50
# 5  6     Charmeleon       6      13  58      64       58       80       65
# 6  7      Charizard       6       7  78      84       78      109       85
#
#    Speed  Generation
# 2     80           1
# 3     80           1
# 4     65           1
# 5     80           1
# 6    100           1

# %%
 # get columns for training the model
train_data = pokeman[["Type 1","Type 2","HP","Attack","Defense","Sp. Atk","Sp. Def" ,"Speed","Generation"]]

# %%
train_data.head()
# Out:
#    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2       9      13  80      82       83      100      100     80           1
# 3       9      13  80     100      123      122      120     80           1
# 4       6      13  39      52       43       60       50     65           1
# 5       6      13  58      64       58       80       65     80           1
# 6       6       7  78      84       78      109       85    100           1

# %%
train_data.shape,y.shape
# Out:
# ((798, 9), (798,))

# %%
# Split data for training and testing purpose
train_x , test_x , train_y , test_y = train_test_split(train_data , y , test_size = 0.15 , random_state = 33)

# %%
# model on simple regression base
regression = LogisticRegression(C=7 , dual=False , max_iter=70 , random_state=33)
regression.fit(train_x,train_y)
y_pred = regression.predict(test_x)
accuracy_score(y_pred=y_pred,y_true=test_y)
# Out:
# 0.95833333333333337

# %%
# model base on svc
svc = SVC(C=1 , gamma=0.001 , kernel="linear" , probability=False , random_state=33 , shrinking=False , tol=0.0001)
svc.fit(train_x,train_y)
y_pred = svc.predict(test_x)
accuracy_score(y_pred=y_pred,y_true=test_y)
# Out:
# 0.93333333333333335

# %%
forest = RandomForestClassifier(max_depth=5 , max_features=5 , n_jobs=15 , random_state=33)
forest.fit(train_x,train_y)
y_pred = forest.predict(test_x)
accuracy_score(y_pred=y_pred,y_true=test_y)
# Out:
# 0.94166666666666665

# %%
neighbours= KNeighborsClassifier()
neighbours.fit(train_x,train_y)
y_pred = neighbours.predict(test_x)
accuracy_score(y_pred=y_pred,y_true=test_y)
# Out:
# 0.92500000000000004

# %%
type_pokeman = pokeman[["Type 1","Type 2"]][:10]

# %%
type_pokeman.plot(kind="bar")
plt.show()
